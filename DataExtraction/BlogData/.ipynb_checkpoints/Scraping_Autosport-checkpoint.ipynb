# %%
import requests
from bs4 import BeautifulSoup as bs
import json

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
def getUrls():
    base_url = "https://www.autosport.com"
    blog_urls = []
    for page_nr in range(22):
        page = requests.get(base_url + "/live/?p=" + str(page_nr))
        soup = bs(page.content, "html.parser")
        blocks = soup.find_all("a", class_="ms-item--live-text")
        for block in blocks:
            title = block.find_all("p", class_="ms-item__title")[0].text
            #if "- Race" in title or 'race' in title:
            if "race" in title.lower():
                blog_urls.append(base_url + block['href'])
    return [u for u in blog_urls if 'f1' in u]

# %% [raw]
#
#
#     # break
#     return None
#     # page = requests.get(url)
#     soup = bs(driver.page_source, "html.parser")
#     # soup = bs(page.content, "html.parser")
#     status = soup.find_all("span", class_="mslt_status-value")[0].text
#     if status != "Stopped":
#         return None
#     title = soup.find_all("h1", class_="ms-entity-detail-header_title")[0].text
#     posts = soup.find_all("div", class_="mslt-msg_text")
#     url_title = title.split("1 ")[1].split(" ")[0].lower()
#     url_date = posts[0].find_all("time", class_="mslt-msg_time")[0]['datetime'][:4]
#     items = []
#     for post in posts:
#         datetime = post.find_all("time", class_="mslt-msg_time")[0]['datetime']
#         content = post.find_all("span", class_="mslt-msg_text-content")[0].text
#         if content != " ":
#             items.append({
#                 "date": datetime,
#                 "content": {
#                     "text": content
#                 }
#             })
#     data = {
#         "title": title,
#         "status": status,
#         "items": items
#     }
#     # json_data = json.dumps(data)
#     filename = "JSONData_Autosport2/" + url_date + "_" + url_title + ".json"
#     with open(filename, 'w') as f:
#         json.dump(data, f)

# %%
blog_urls = getUrls()

# %%
blog_urls
# Out:
# ['https://www.autosport.com/f1/live-text/f1-abu-dhabi-gp-live-commentary-and-updates-race/1120962/',
#  'https://www.autosport.com/f1/live-text/f1-las-vegas-gp-live-commentary-and-updates-race/1120876/',
#  'https://www.autosport.com/f1/live-text/f1-brazilian-gp-live-commentary-and-updates-race/1120712/',
#  'https://www.autosport.com/f1/live-text/f1-brazilian-gp-live-commentary-and-updates-sprint-quali-race/1120708/',
#  'https://www.autosport.com/f1/live-text/f1-mexican-gp-live-commentary-and-updates-race/1120619/',
#  'https://www.autosport.com/f1/live-text/f1-united-states-gp-live-commentary-and-updates-race/1120475/',
#  'https://www.autosport.com/f1/live-text/f1-united-states-gp-live-commentary-and-updates-sprint-quali-race/1120471/',
#  'https://www.autosport.com/f1/live-text/f1-qatar-gp-live-commentary-and-updates-race/1120165/',
#  'https://www.autosport.com/f1/live-text/f1-qatar-gp-live-commentary-and-updates-sprint-quali-race/1120161/',
#  'https://www.autosport.com/f1/live-text/f1-japanese-gp-live-commentary-and-updates-race/1120068/',
#  'https://www.autosport.com/f1/live-text/f1-singapore-gp-live-commentary-and-updates-race/1120002/',
#  'https://www.autosport.com/f1/live-text/f1-abu-dhabi-gp-live-commentary-and-updates-race/1120962/',
#  'https://www.autosport.com/f1/live-text/belgian-grand-prix-race-day-19829/19829/',
#  'https://www.autosport.com/f1/live-text/hungarian-grand-prix-race-day-19845/19845/',
#  'https://www.autosport.com/f1/live-text/german-grand-prix-race-day-19849/19849/',
#  'https://www.autosport.com/f1/live-text/british-grand-prix-race-day-19854/19854/',
#  'https://www.autosport.com/f1/live-text/austrian-grand-prix-race-day-19857/19857/',
#  'https://www.autosport.com/f1/live-text/french-grand-prix-race-day-19862/19862/',
#  'https://www.autosport.com/f1/live-text/canadian-grand-prix-race-day-19870/19870/',
#  'https://www.autosport.com/f1/live-text/monaco-grand-prix-race-day-19873/19873/',
#  'https://www.autosport.com/f1/live-text/spanish-grand-prix-race-day-19882/19882/',
#  'https://www.autosport.com/f1/live-text/azerbaijan-grand-prix-race-day-19888/19888/',
#  'https://www.autosport.com/f1/live-text/chinese-grand-prix-race-day-19895/19895/',
#  'https://www.autosport.com/f1/live-text/bahrain-grand-prix-race-day-19897/19897/']

# %%
blog_urls[0].split('-text/')[1].split
# Out:
# ['https://www.autosport.com/f1/live',
#  'f1-abu-dhabi-gp-live-commentary-and-updates-race/1120962/']

# %%
def getBlogs(url):
    base_url = "https://www.autosport.com"
    try: page = requests.get(url)
    except: return None
    soup = bs(page.content, "html.parser")
    status = soup.find_all("span", class_="mslt_status-value")[0].text
    if status != "Stopped": return None
    # title = soup.find_all("h1", class_="text-article-title-dynamic")[0].text
    first_post = soup.find("div", class_="mslt-msg_text")
    # first_post = soup.find_all("div", class_="mslt-msg_text")[0]
    # url_title = title.split("1 ")[1].split(" ")[0].lower()
    url_title = url.split('-text/')[1]
    if 'gp' in url_title: url_title = url_title.split('-gp')[0]
    elif 'grand' in url_title: url_title = url_title.split('-grand')[0]
    if 'f1-' in url_title: url_title = url_title.replace('f1-', '')
    url_date = first_post.find_all("time", class_="mslt-msg_time")[0]['datetime'][:4]
    button = soup.find("a", attrs={"data-id": "nextPage"})
    if not button: return None
    # button = soup.find_all("a", class_="msnt-button")[0]#"ms-pager__button")[0]
    # except IndexError: return None
    but_href = button['href'][:-1]
    empty_msg = False
    page = 1
    items = {}
    while not empty_msg:
        data_url = base_url + but_href + str(page)
        resp = requests.get(data_url)
        json_data = json.loads(resp.content)
        if json_data['html'] == "": empty_msg = True
        else:
            html = json_data['html']
            soup_nw = bs(html, "html.parser")
            posts = soup_nw.find_all("div", class_="mslt-msg_text")
            for post in posts:
                datetime = post.find_all("time", class_="mslt-msg_time")[0]['datetime']
                content = post.find_all("span", class_="mslt-msg_text-content")[0].text
                if '"' in content: continue
                items[datetime] = content
            page += 1
    # data = {
    #     "title": title,
    #     "status": status,
    #     "items": items
    # }
    filename = "DataSet/" + url_date + "_" + url_title + ".json"
    with open(filename, 'w') as f:
        json.dump(items, f)

# %%
for url in blog_urls:
    getBlogs(url)
